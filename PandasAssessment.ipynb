# %% [markdown]
# <a href="https://colab.research.google.com/github/shalinikarthick/shalinikarthick/blob/main/PandasAssessment.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ###### Assessment

# %% [markdown]
# ###### I am going to provide two .csv files , you are supposed to work on them and have to provide solutions to the following problems

# %% [markdown]
# ###### import necessary libraries

# %%
import pandas as pd
import matplotlib.pyplot as plt

# %% [markdown]
# ###### merge those two csv files (after getting as dataframes, get them as a single dataframe)

# %%
df1= pd.read_csv("/content/college_1.csv", )
df2= pd.read_csv("/content/college_2.csv")

# %%
df1['Name'] = df1['Name'].str.upper().str.strip()
df1
# Out:
#               Name  python  mysql  Previous Geekions  CodeKata Score  \
# 0        A.DHARANI    82.0   20.0              24500           24500
# 1       V.JEEVITHA    82.0   20.0              21740           21740
# 2      HEMAVATHI.R   100.0  100.0              19680           19680
# 3      MUGUNTHAN S   100.0   47.0              10610           10610
# 4      SATHAMMAI.S   100.0    8.0               8980            8980
# ..             ...     ...    ...                ...             ...
# 79    KARTHIKEYANS    45.0    0.0                  0               0
# 80        BARATH.P    29.0    0.0                  0               0
# 81   N.AJITH KUMAR    82.0    0.0                  0               0
# 82    MOHAMED NABI     0.0    0.0                  0               0
# 83  YASER AHAMED.A     0.0   27.0                  0               0
#
#                                 Department  Rising
# 0         Computer Science and Engineering       0
# ...

# %%
df2['Name'] = df2['Name'].str.upper().str.strip()
df2
# Out:
#                       Name  python  python_en  mysql  computational_thinking  \
# 0            ASHOK KUMAR K     100          0     31                       9
# 1                  CHANDRU       0         20      0                       0
# 2        GANESH RAMKUMAR R      -1         55     24                       6
# 3          BODIPUDI HARINI      -1          0     35                      -1
# 4                VIINU V P      -1        100     24                      -1
# 5               POOJITHA Y       0         78     35                       0
# 6   GOWTHAM CHANDRASEKARAN      -1          0      0                       3
# 7                GOWTHAM R      -1         60      4                       6
# 8                 SHIFAK N      58          0      0                       0
# 9                   BALAJI      -1        100     20                       0
# 10                RUSHITHA      -1         15     62                       9
# ...

# %%
bgdf= pd.concat([df1,df2], ignore_index= True)
bgdf
# Out:
#               Name  python  mysql  Previous Geekions  CodeKata Score  \
# 0        A.DHARANI    82.0   20.0              24500           24500
# 1       V.JEEVITHA    82.0   20.0              21740           21740
# 2      HEMAVATHI.R   100.0  100.0              19680           19680
# 3      MUGUNTHAN S   100.0   47.0              10610           10610
# 4      SATHAMMAI.S   100.0    8.0               8980            8980
# ..             ...     ...    ...                ...             ...
# 114  PRAVEEN RAJ J    24.0    0.0               2380            2380
# 115     AMARNATH D    -1.0   12.0               1890            1890
# 116           BALA    32.0    0.0               1720            1720
# 117           XY Z    -1.0   -1.0                  0               0
# 118      HARIHARAN    -1.0   -1.0                  0               0
#
#                                     Department  Rising  python_en  \
# 0             Computer Science and Engineering       0        NaN
# ...

# %%
bgdf['python_en']= bgdf['python_en'].fillna(0)
bgdf['computational_thinking']= bgdf['computational_thinking'].fillna(0)
bgdf
# Out:
#               Name  python  mysql  Previous Geekions  CodeKata Score  \
# 0        A.DHARANI    82.0   20.0              24500           24500
# 1       V.JEEVITHA    82.0   20.0              21740           21740
# 2      HEMAVATHI.R   100.0  100.0              19680           19680
# 3      MUGUNTHAN S   100.0   47.0              10610           10610
# 4      SATHAMMAI.S   100.0    8.0               8980            8980
# ..             ...     ...    ...                ...             ...
# 114  PRAVEEN RAJ J    24.0    0.0               2380            2380
# 115     AMARNATH D    -1.0   12.0               1890            1890
# 116           BALA    32.0    0.0               1720            1720
# 117           XY Z    -1.0   -1.0                  0               0
# 118      HARIHARAN    -1.0   -1.0                  0               0
#
#                                     Department  Rising  python_en  \
# 0             Computer Science and Engineering       0        0.0
# ...

# %% [markdown]
# ###### Take each csv file , split that csv file into multiple categories (example csv files are added in the repo)

# %% [markdown]
# ###### consider if the codekata score exceeds 15000 points(present week) then make a csv on those observations as Exceeded expectations.csv

# %% [markdown]
# ###### if  10000<codekata score<15000   (Reached_expectations.csv)

# %% [markdown]
# ###### if  7000<codekata score<10000   (Needs_Improvement.csv)

# %% [markdown]
# ###### if  codekate score < 7000        (Unsatisfactory.csv)

# %%
bgdf[bgdf['CodeKata Score'] >= 15000].sort_values(by='CodeKata Score', ascending= False).to_csv("/content/Exceeded_expectations.csv")

# %%
bgdf[(bgdf['CodeKata Score'] >= 10000) & (df1['CodeKata Score'] < 15000)].sort_values(by='CodeKata Score', ascending= False).to_csv("/content/Reached_expectations.csv")

# %%
bgdf[(bgdf['CodeKata Score'] >= 7000) & (df1['CodeKata Score'] < 10000)].sort_values(by='CodeKata Score', ascending= False).to_csv("/content/Needs_improvement.csv")

# %%
bgdf[bgdf['CodeKata Score'] < 7000].sort_values(by='CodeKata Score', ascending= False).to_csv("/content/Unsatisfactory.csv")

# %% [markdown]
# ###### Average of previous week geekions vs this week geekions (i.e Previous Geekions vs CodeKata Score)

# %%
bgdfperf= bgdf.pivot_table(index="Department", values=['Previous Geekions','CodeKata Score', 'Rising'], aggfunc='mean')
bgdfperf['CodeKata Score'],bgdfperf['Previous Geekions'],bgdfperf['Rising']= round(bgdfperf['CodeKata Score'], 2), round(bgdfperf['Previous Geekions'], 2), round(bgdfperf['Rising'], 2)
bgdfperf
# Out:
#                                            CodeKata Score  Previous Geekions  \
# Department
# Computer Science and Engineering                  5079.76            4792.62
# Electronics and Communication Engineering         2777.82            2751.92
# Electronics and Electrical Engineering            3164.71            2822.35
#
#                                            Rising
# Department
# Computer Science and Engineering           287.14
# Electronics and Communication Engineering   25.90
# Electronics and Electrical Engineering     342.35

# %%
plt.figure(figsize = (10,8))

plt.plot(bgdfperf['Previous Geekions'])
plt.plot(bgdfperf['CodeKata Score'], color= 'red')
plt.show()

# %% [markdown]
# ###### No of students participated

# %%
bgdf.pivot_table(index="Department", values='Name', aggfunc= 'count')
# Out:
#                                            Name
# Department
# Computer Science and Engineering             63
# Electronics and Communication Engineering    39
# Electronics and Electrical Engineering       17

# %% [markdown]
# ###### #Average completion of python course or my_sql or python english or computational thinking

# %%
bgdf.pivot_table(index="Department", values=['python', 'mysql', 'python_en', 'computational_thinking'], aggfunc= 'mean')
# Out:
#                                            computational_thinking      mysql  \
# Department
# Computer Science and Engineering                         0.365079  22.178571
# Electronics and Communication Engineering                1.179487  27.108974
# Electronics and Electrical Engineering                   0.470588  20.117647
#
#                                               python  python_en
# Department
# Computer Science and Engineering           61.015873   7.730159
# Electronics and Communication Engineering  39.294872   9.000000
# Electronics and Electrical Engineering     64.205882  11.764706

# %% [markdown]
# ###### rising star of the week (top 3 candidate who performed well in that particular week)

# %%
bgdf[['Name','Rising']].query('Rising > 0').sort_values(by='Rising', ascending=False).head(3)
# Out:
#                   Name  Rising
# 92            SHIFAK N    3140
# 86   GANESH RAMKUMAR R    2000
# 102     NARASIMHAN Y L    2000

# %% [markdown]
# ###### Shining stars of the week (top 3 candidates who has highest geekions)

# %%
bgdf[['Name','CodeKata Score']].sort_values(by='CodeKata Score', ascending=False, ).head(3)
# Out:
#           Name  CodeKata Score
# 0    A.DHARANI           24500
# 1   V.JEEVITHA           21740
# 2  HEMAVATHI.R           19680

# %% [markdown]
# ###### Department wise codekata performence (pie chart)

# %%
piechart= bgdf.pivot_table(index='Department', aggfunc="sum", values=["CodeKata Score", "Previous Geekions", "Rising"] )
piechart
# Out:
#                                            CodeKata Score  Previous Geekions  \
# Department
# Computer Science and Engineering                   320025             301935
# Electronics and Communication Engineering          108335             107325
# Electronics and Electrical Engineering              53800              47980
#
#                                            Rising
# Department
# Computer Science and Engineering            18090
# Electronics and Communication Engineering    1010
# Electronics and Electrical Engineering       5820

# %%
fig= plt.figure(figsize = (20,8))
plt.subplot(1,2,1)
plt.pie(piechart['CodeKata Score'], labels=piechart.index, autopct='%1.1f%%')
plt.subplot(1,2,2)
plt.pie(piechart['Previous Geekions'], labels=piechart.index, autopct='%1.1f%%')

plt.show
# Out:
# <function matplotlib.pyplot.show(*args, **kw)>

# %% [markdown]
# ###### Department wise toppers (horizantal bar graph or any visual representations of your choice)

# %%
deprankers= bgdf.groupby('Department').apply(lambda x : x.sort_values(by = 'CodeKata Score', ascending = False).head(1).reset_index(drop = True))[['Name','CodeKata Score']]
deprankers
# Out:
#                                                         Name  CodeKata Score
# Department
# Computer Science and Engineering          0        A.DHARANI           24500
# Electronics and Communication Engineering 0  BODIPUDI HARINI           10040
# Electronics and Electrical Engineering    0    ASHOK KUMAR K           19400

# %%
plt.bar(deprankers['Name'], deprankers['CodeKata Score'])
# Out:
# <BarContainer object of 3 artists>
